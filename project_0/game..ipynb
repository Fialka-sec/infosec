# %% [markdown]
# #Игра первого уровня

# %% [markdown]
# #Игра второго уровня

# %%
import game_v2
# Out:
# Ваш алгорит угадывает число в среднем за: 101 попыток

# %%
game_v2.score_game(game_v2.random_predict)
# Out:
# Ваш алгорит угадывает число в среднем за: 101 попыток
# 101

# %%
from game_v2 import score_game
from game_v2 import random_predict

# %%
score_game(random_predict)
# Out:
# Ваш алгорит угадывает число в среднем за: 101 попыток
# 101

# %%
n = 10
z = n
n = 5
